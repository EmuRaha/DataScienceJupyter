# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#           SYMBOL  SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0      20MICRONS      EQ   10-Jul-2020       32.00       31.85       34.50
# 1     21STCENMGM      EQ   10-Jul-2020       11.10       11.10       11.10
# 2     3IINFOTECH      EQ   10-Jul-2020        2.75        2.70        2.75
# 3        3MINDIA      EQ   10-Jul-2020    19498.95    19301.00    19599.00
# 4      509GS2022      GS   10-Jul-2020      103.95       99.00      104.00
# ...          ...     ...           ...         ...         ...         ...
# 1927   ZODJRDMKJ      EQ   10-Jul-2020       35.70       37.45       39.25
# 1928        ZOTA      EQ   10-Jul-2020      143.65      144.30      144.90
# 1929       ZUARI      EQ   10-Jul-2020       99.45       99.20      101.25
# 1930   ZUARIGLOB      EQ   10-Jul-2020       55.60       54.70       56.00
# 1931   ZYDUSWELL      EQ   10-Jul-2020     1381.65     1374.00     1379.60
#
#       LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
df.head()
# Out:
#        SYMBOL  SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS      EQ   10-Jul-2020       32.00       31.85       34.50
# 1  21STCENMGM      EQ   10-Jul-2020       11.10       11.10       11.10
# 2  3IINFOTECH      EQ   10-Jul-2020        2.75        2.70        2.75
# 3     3MINDIA      EQ   10-Jul-2020    19498.95    19301.00    19599.00
# 4   509GS2022      GS   10-Jul-2020      103.95       99.00      104.00
#
#    LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0      31.50       32.40        32.30      32.49         37441          12.17
# 1      10.90       10.90        10.90      10.95           136           0.01
# 2       2.65        2.65         2.65       2.67       3163425          84.32
# 3   19301.00    19501.00     19504.05   19482.85          2646         515.52
# 4      99.00       99.00        99.00     100.25             4           0.00
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# ...

# %%
df.shape
# Out:
# (1932, 15)

# %%
df.iloc[1:4,4:9]
# Out:
#    OPEN_PRICE  HIGH_PRICE  LOW_PRICE  LAST_PRICE  CLOSE_PRICE
# 1        11.1       11.10      10.90       10.90        10.90
# 2         2.7        2.75       2.65        2.65         2.65
# 3     19301.0    19599.00   19301.00    19501.00     19504.05

# %%
print(df['SYMBOL'].dtype)
# Out:
# object

# %%
print(df['PREV_CLOSE'].dtype)
# Out:
# float64

# %%
df['PREV_CLOSE']
# Out:
# 0          32.00
# 1          11.10
# 2           2.75
# 3       19498.95
# 4         103.95
#           ...
# 1927       35.70
# 1928      143.65
# 1929       99.45
# 1930       55.60
# 1931     1381.65
# Name: PREV_CLOSE, Length: 1932, dtype: float64
